# %%
from datetime import datetime
import os 
import pandas as pd
import numpy as np

# %%
data = "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-02-18_validate_regenie_pipeline_by_replicating_AoU_gwas_results"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil ls "$WORKSPACE_BUCKET/notebooks/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input/"

# %%
##import sample, demographics, phenotypemap, and ancestry files

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/mcc2_phecodex_table.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-02-18_validate_regenie_pipeline_by_replicating_AoU_gwas_results"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/phecodex_info.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-02-18_validate_regenie_pipeline_by_replicating_AoU_gwas_results"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/updated_phecodex_map.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-02-18_validate_regenie_pipeline_by_replicating_AoU_gwas_results"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/ancestry.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-02-18_validate_regenie_pipeline_by_replicating_AoU_gwas_results"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/demographics_table.csv "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-02-18_validate_regenie_pipeline_by_replicating_AoU_gwas_results"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/v7_has_srWGS.csv "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-02-18_validate_regenie_pipeline_by_replicating_AoU_gwas_results"

# %%
#import genetic data : acaf files, pc files, relatedness and WGS_qc files to remove

# %%
# !gsutil -u $GOOGLE_PROJECT ls gs://fc-aou-datasets-controlled/v7/known_issues/

# %%
# !gsutil -u $GOOGLE_PROJECT ls gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/aux/vat

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -u $GOOGLE_PROJECT -m cp  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/aux/relatedness/relatedness_flagged_samples.tsv "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-02-18_validate_regenie_pipeline_by_replicating_AoU_gwas_results"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -u $GOOGLE_PROJECT -m cp  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/aux/qc/flagged_samples.tsv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-02-18_validate_regenie_pipeline_by_replicating_AoU_gwas_results"

# %%
def get_ancestry_pcs_tsv_file_and_save():
    
    # !gsutil -u $GOOGLE_PROJECT cp gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/aux/ancestry/ancestry_preds.tsv/ .
   
    #ancestry_pred = pd.read_csv("ancestry_preds.tsv", delimiter="\t")   
    
    #return ancestry_pred

# %%
#get acaf bgen files

# %%
# !gsutil -u ${GOOGLE_PROJECT} ls gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/

# %%
def get_acaf_plink_files():
    
    start = datetime.now()
    bucket = os.getenv("WORKSPACE_BUCKET")
    genomic_location = os.getenv("CDR_STORAGE_PATH")
    
        
    # !mkdir -p acaf_v7_plink_files/
    
    # !gsutil -u $GOOGLE_PROJECT -m cp -r gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr16.bed  acaf_v7_plink_files/
    # !gsutil -u $GOOGLE_PROJECT -m cp -r gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr16.bim  acaf_v7_plink_files/
    # !gsutil -u $GOOGLE_PROJECT -m cp -r gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr16.fam  acaf_v7_plink_files/
    
get_acaf_plink_files()
