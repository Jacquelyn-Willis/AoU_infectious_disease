# %%
from datetime import datetime
import os 
import pandas as pd
import numpy as np

# %%
data = "/home/jupyter/workspaces/20251104infectiousdiseasephewasduplicate/data/2025-12-13_preparing_cohort_genotype_files_for_regenie_input"

scratch =  "/home/jupyter/workspaces/20251104infectiousdiseasephewasduplicate/scracth/2025-12-13_preparing_cohort_genotype_files_for_regenie_input"

# %%
# !gsutil -u ${GOOGLE_PROJECT} ls gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/

# %%
def get_acaf_pgen_files():
    
    start = datetime.now()
    bucket = os.getenv("WORKSPACE_BUCKET")
    genomic_location = os.getenv("CDR_STORAGE_PATH")
    
        
    # !mkdir -p acaf_pgen_files
    
    # !gsutil -u $GOOGLE_PROJECT -m cp -r gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/ acaf_pgen_files/

# %%
#function calls

get_acaf_pgen_files()
