# %%
from datetime import datetime
import os

# %%
data = "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2025-12-13_preparing_cohort_genotype_files_for_regenie_input"

results = "/home/jupyter/workspaces/infectiousdiseasephewas2/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"

scratch =  "/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"

#!mkdir {scratch}

# %%
# !bash -lc 'rm -f acaf_pmerge_list.txt; for c in {1..22} X Y; do echo acaf_threshold.chr${c} >> acaf_pmerge_list.txt; done'

# %%
# %%bash
#
# pgen_dir_in="/home/jupyter/workspaces/infectiousdiseasephewas2/data/2025-12-13_preparing_cohort_genotype_files_for_regenie_input/acaf_pgen_chr22/"
#
# pgen_dir_out="/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
#
# plink2 \
#     --pfile ${pgen_dir_in}/acaf_threshold.chr22 \
#     --threads 8 \
#     --maf 0.01 \
#     --hwe 1e-6 .001 \
#     --geno 0.1 \
#     --mind 0.1 \
#     --set-missing-var-ids @:# \
#     --make-pgen \
#     --out ${pgen_dir_out}/acaf_threshold.chr22.qc

# %%
# %%bash
#
# data="/home/jupyter/workspaces/infectiousdiseasephewas2/data/2025-12-13_preparing_cohort_genotype_files_for_regenie_input"
#
# results="/home/jupyter/workspaces/infectiousdiseasephewas2/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
#
#
#
# plink2 \
#     --pfile ${data}/acaf_pgen_chr22/acaf_threshold.chr22 \
#     --threads 8 \
#     --maf 0.05 \
#     --max-maf 0.95 \
#     --geno 0.9 \
#     --mac 100 \
#     --hwe 1e-25 keep-fewhet \
#     --make-pgen \
#     --out ${results}/acaf_threshold.chr22_TEST.qc

# %%
# %%bash
#
# pgen_dir_in="/home/jupyter/workspaces/infectiousdiseasephewas2/data/2025-12-13_preparing_cohort_genotype_files_for_regenie_input/acaf_pgen_files/pgen/"
#
# pgen_dir_out="/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
#
# plink2 \
#     --pfile ${pgen_dir_in}/acaf_threshold.chr21 \
#     --threads 8 \
#     --maf 0.01 \
#     --hwe 1e-6 .001 \
#     --geno 0.1 \
#     --mind 0.1 \
#     --set-missing-var-ids @:# \
#     --make-pgen \
#     --out ${pgen_dir_out}/acaf_threshold.chr21.qc

# %%
# %%bash
#
# pgen_dir_in="/home/jupyter/workspaces/infectiousdiseasephewas2/data/2025-12-13_preparing_cohort_genotype_files_for_regenie_input/acaf_pgen_chr22/"
#
# pgen_dir_out="/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
#
# plink2 \
#     --pfile ${pgen_dir_in}/acaf_threshold.chr22 \
#     --threads 8 \
#     --maf 0.01 \
#     --hwe 1e-300 \
#     --geno 0.1 \
#     --mind 0.1 \
#     --set-missing-var-ids @:# \
#     --make-pgen \
#     --out ${pgen_dir_out}/acaf_threshold.chr22.qc

# %%
# %%bash
#
# pgen_dir_in="/home/jupyter/workspaces/infectiousdiseasephewas2/data/2025-12-13_preparing_cohort_genotype_files_for_regenie_input/acaf_pgen_chr22/"
#
# pgen_dir_out="/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
#
# plink2 \
#     --pfile ${pgen_dir_in}/acaf_threshold.chr22 \
#     --threads 8 \
#     --maf 0.01 \
#     --hwe 1e-15 .001 \
#     --set-missing-var-ids @:# \
#     --make-pgen \
#     --out ${pgen_dir_out}/acaf_threshold.chr22.qc

# %%
# %%bash
#
#
# pgen_dir_data="/home/jupyter/workspaces/infectiousdiseasephewas2/data/2025-12-13_preparing_cohort_genotype_files_for_regenie_input/acaf_pgen_files/pgen"
#
# pgen_dir_scr="/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
#
#
#
# for chr in {1..22}; do
#   plink2 \
#     --pfile ${pgen_dir_scr}/acaf_threshold.chr${chr}.qc \
#     --indep-pairwise 1000 100 0.1 \
#     --out ${pgen_dir_scr}/acaf_threshold.chr${chr}.ld_prune
# done

# %%
pgen_dir = "/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"  # where the .qc pfiles actually live
scratch_dir = "/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"

chroms = range(1, 23)

with open(f"{scratch_dir}/acaf_qc_pmerge_list.txt", "w") as f:
    for c in chroms:
        # This must match your plink2 --out prefix when you did per-chr QC
        f.write(f"{pgen_dir}/acaf_threshold.chr{c}.qc\n")

# %%
# %%bash
#
# pgen_dir_scr="/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
#
#
# plink2 \
#   --pmerge-list ${pgen_dir_scr}/acaf_qc_pmerge_list.txt \
#   --set-missing-var-ids @:# \
#   --make-pgen \
#   --out ${pgen_dir_scr}/acaf_threshold.allchr.qc_merge

# %%
# %%bash
#
#
# pgen_dir_scr="/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
#
# cat ${pgen_dir_scr}/acaf_threshold.chr*.ld_prune.prune.in > ${pgen_dir_scr}/acaf_threshold.allchr.ld_prune.prune.in

# %%
# %%bash
#
# pgen_dir_scr="/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
# pgen_dir_res="/home/jupyter/workspaces/infectiousdiseasephewas2/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input"
#
#
# plink2 \
#   --pfile ${pgen_dir_scr}/acaf_threshold.allchr.qc_merge \
#   --extract ${pgen_dir_scr}/acaf_threshold.allchr.ld_prune.prune.in \
#   --make-pgen \
#   --out ${pgen_dir_res}/acaf_threshold.step1_snps

# %%
my_bucket = os.getenv('WORKSPACE_BUCKET')
my_bucket

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp /home/jupyter/workspaces/infectiousdiseasephewas2/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input/acaf_threshold.step1_snps.log "$WORKSPACE_BUCKET/notebooks/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input/"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp /home/jupyter/workspaces/infectiousdiseasephewas2/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input/acaf_threshold.step1_snps.psam "$WORKSPACE_BUCKET/notebooks/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input/"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp /home/jupyter/workspaces/infectiousdiseasephewas2/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input/acaf_threshold.step1_snps.pvar "$WORKSPACE_BUCKET/notebooks/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input/"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp /home/jupyter/workspaces/infectiousdiseasephewas2/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input/acaf_threshold.step1_snps.pgen "$WORKSPACE_BUCKET/notebooks/results/2025-12-12_preparing_cohort_genotype_files_for_regenie_input/"
