# %%
from datetime import datetime
import os 
import pandas as pd
import numpy as np

start = datetime.now()
bucket = os.getenv("WORKSPACE_BUCKET")
bucket

# %%
# %%bash
# gsutil ls -lh "$WORKSPACE_BUCKET/notebooks/2025-10-06_Pilot_infectious_disease_PheWAS/"

# %%
genomic_location = os.getenv("CDR_STORAGE_PATH")
genomic_location

# %%
# !gsutil -u ${GOOGLE_PROJECT} ls gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel

# %%
plink_path = "gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/clinvar/plink_bed"

# %%
# !mkdir -p plink

# %%
# !gsutil -u $GOOGLE_PROJECT -m cp gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/clinvar/plink_bed/*chr22* plink/

# %%
# !gsutil -m cp gs://fc-secure-ff68a895-e88d-426e-9ae4-b3802c51b53b/data/test_plink* plink/

# %%
ls plink/

# %%
bim = pd.read_csv('/home/jupyter/workspaces/duplicateofcreatinginfectiousdiseasecohorts/2025-10-06_Pilot_infectious_disease_PheWAS/plink/chr22.bim', delimiter="\t")

# %%
bim.iloc[100:200]

# %%
fam =  pd.read_csv('/home/jupyter/workspaces/duplicateofcreatinginfectiousdiseasecohorts/2025-10-06_Pilot_infectious_disease_PheWAS/plink/chr22.fam', delimiter="\t")

# %%
fam
