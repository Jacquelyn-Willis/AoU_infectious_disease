# %%
import os

bucket = os.getenv("WORKSPACE_BUCKET")
bucket

# %%
data = "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-01-27_curate_controls_for_PheWAS_study"
data2 = "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2025-12-13_preparing_cohort_genotype_files_for_regenie_input"

scratch =  "/home/jupyter/workspaces/infectiousdiseasephewas2/scratch/2026-01-27_curate_controls_for_PheWAS_study"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil ls "$WORKSPACE_BUCKET/notebooks/results/"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/mcc2_phecodex_table.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-01-27_curate_controls_for_PheWAS_study"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/phecodex_info.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-01-27_curate_controls_for_PheWAS_study"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/updated_phecodex_map.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-01-27_curate_controls_for_PheWAS_study"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/phecode_info.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-01-27_curate_controls_for_PheWAS_study"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/expanded_phecode.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-01-27_curate_controls_for_PheWAS_study"

# %%
# %%bash
# # -m = parallel; -r = recursive
# gsutil -m cp  $WORKSPACE_BUCKET/notebooks/results/mcc2_phecode_table.csv  "/home/jupyter/workspaces/infectiousdiseasephewas2/data/2026-01-27_curate_controls_for_PheWAS_study"
